# %%
from aps_toolkit import Auth
from revit_meows import APSRevit
import warnings
warnings.filterwarnings("ignore")

# %%
# client_id = "<>"
# client_secret = "<>"
# token = Auth(client_id,client_secret).auth3leg()
token = Auth().auth3leg()

# %%
urn  = "dXJuOmFkc2sud2lwcHJvZDpmcy5maWxlOnZmLk9kOHR4RGJLU1NlbFRvVmcxb2MxVkE_dmVyc2lvbj0zNg"
revit_data = APSRevit(urn,token)
df = revit_data.get_all_data()
df.head()
# Out:
#    objectid                                    name ElementId  \
# 0        97  Seating-LAMMHULTS-PENNE-Chair [289790]    289790
# 1        98                   Krevet-002-2 [291052]    291052
# 2      4168                          Table [296049]    296049
# 3        99                     Basic Wall [291086]    291086
# 4       100                     Basic Wall [291127]    291127
#
#                                       externalId  \
# 0  5bb069ca-e4fe-4e63-be31-f8ac44e80d30-00046bfe
# 1  5bb069ca-e4fe-4e63-be31-f8ac44e80d30-000470ec
# 2  6d22740f-4d3f-4cc6-a442-8c98ddd54f1f-00048471
# 3  5bb069ca-e4fe-4e63-be31-f8ac44e80d30-0004710e
# 4  5bb069ca-e4fe-4e63-be31-f8ac44e80d30-00047137
#
#                       Family Name    Level Elevation from Level  \
# 0  Seating-LAMMHULTS-PENNE-Chair   Level 1             0.000 mm
# 1                   Krevet-002-2   Level 1             0.000 mm
# 2                          Table       NaN                  NaN
# 3                     Basic Wall       NaN                  NaN
# 4                     Basic Wall       NaN                  NaN
#
#               Host Offset from Host Moves With Nearby Elements  ...  \
# 0  Level : Level 1         0.000 mm                         No  ...
# 1  Level : Level 1         0.000 mm                         No  ...
# 2              NaN              NaN                         No  ...
# 3              NaN              NaN                        NaN  ...
# 4              NaN              NaN                        NaN  ...
#
#   IfcSite GUID IfcBuilding GUID IfcProject GUID Project Issue Date  \
# 0          NaN              NaN             NaN                NaN
# 1          NaN              NaN             NaN                NaN
# 2          NaN              NaN             NaN                NaN
# 3          NaN              NaN             NaN                NaN
# 4          NaN              NaN             NaN                NaN
#
#   Project Status Client Name Project Address Project Name Project Number  \
# 0            NaN         NaN             NaN          NaN            NaN
# 1            NaN         NaN             NaN          NaN            NaN
# 2            NaN         NaN             NaN          NaN            NaN
# 3            NaN         NaN             NaN          NaN            NaN
# 4            NaN         NaN             NaN          NaN            NaN
#
#   Route Analysis Settings
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 389 columns]

# %%
df2 = revit_data.get_all_data(is_field_param=True, is_include_category=True)
df2.head()
# Out:
#    objectid                                    name ElementId  \
# 0        97  Seating-LAMMHULTS-PENNE-Chair [289790]    289790
# 1        98                   Krevet-002-2 [291052]    291052
# 2      4168                          Table [296049]    296049
# 3        99                     Basic Wall [291086]    291086
# 4       100                     Basic Wall [291127]    291127
#
#                                       externalId  \
# 0  5bb069ca-e4fe-4e63-be31-f8ac44e80d30-00046bfe
# 1  5bb069ca-e4fe-4e63-be31-f8ac44e80d30-000470ec
# 2  6d22740f-4d3f-4cc6-a442-8c98ddd54f1f-00048471
# 3  5bb069ca-e4fe-4e63-be31-f8ac44e80d30-0004710e
# 4  5bb069ca-e4fe-4e63-be31-f8ac44e80d30-00047137
#
#                       Family Name   Category [Constraints]Level  \
# 0  Seating-LAMMHULTS-PENNE-Chair   Furniture            Level 1
# 1                   Krevet-002-2   Furniture            Level 1
# 2                          Table   Furniture                NaN
# 3                     Basic Wall       Walls                NaN
# 4                     Basic Wall       Walls                NaN
#
#   [Constraints]Elevation from Level [Constraints]Host  \
# 0                          0.000 mm   Level : Level 1
# 1                          0.000 mm   Level : Level 1
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
#
#   [Constraints]Offset from Host  ... [IFC Parameters]IfcSite GUID  \
# 0                      0.000 mm  ...                          NaN
# 1                      0.000 mm  ...                          NaN
# 2                           NaN  ...                          NaN
# 3                           NaN  ...                          NaN
# 4                           NaN  ...                          NaN
#
#   [IFC Parameters]IfcBuilding GUID [IFC Parameters]IfcProject GUID  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
#
#   [Other]Project Issue Date [Other]Project Status [Other]Client Name  \
# 0                       NaN                   NaN                NaN
# 1                       NaN                   NaN                NaN
# 2                       NaN                   NaN                NaN
# 3                       NaN                   NaN                NaN
# 4                       NaN                   NaN                NaN
#
#   [Other]Project Address [Other]Project Name [Other]Project Number  \
# 0                    NaN                 NaN                   NaN
# 1                    NaN                 NaN                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    NaN                 NaN                   NaN
#
#   [Route Analysis]Route Analysis Settings
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 393 columns]

# %%
cates = revit_data.get_all_categories()
print(cates)
# Out:
# ['Furniture', 'Walls', 'Doors', 'Specialty Equipment', 'Mechanical Equipment', 'Floors', 'Windows', 'Generic Models', 'Rooms', 'Lighting Fixtures', 'Electrical Equipment', 'Electrical Fixtures', 'Ceilings']
